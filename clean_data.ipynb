# %%
# !pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.2.2)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2024.1)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5

# %%
import pandas as pd

# Load the dataset
file_path = '/workspaces/emigrant-country-dashboard/Emigrant-1981-2022-MajorCountry.xlsx'
df = pd.read_excel(file_path, header=None)

# Select specific rows and columns, then combine and clean headers
df = df.iloc[2:46, :12]
headers = df.iloc[0].fillna('') + ' ' + df.iloc[1].fillna('')
headers = headers.str.strip().str.replace(' ', '_')
df.columns = headers
df = df.iloc[2:].reset_index(drop=True)
df.rename(columns={df.columns[0]: 'Year'}, inplace=True)

# Reshape the data to long format
df_long = df.melt(id_vars=['Year'], var_name='Country', value_name='Emigrant_Count')

# Convert 'Year' column to numeric, ensure 'Emigrant_Count' is integer, and fill in nulls/blanks with 0
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long['Emigrant_Count'] = df_long['Emigrant_Count'].fillna(0).astype(int)
df_long = df_long.reset_index(drop=True)

# Display the resulting DataFrame and save it to a new Excel file
df_long.info()
print(df_long.head())
df_long.to_excel('/workspaces/emigrant-country-dashboard/Cleaned_Emigrant_Data.xlsx', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            462 non-null    int64
#  1   Country         462 non-null    object
#  2   Emigrant_Count  462 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 11.0+ KB
#    Year Country  Emigrant_Count
# 0  1981    USA*           40307
# 1  1982    USA*           44438
# 2  1983    USA*           34794
# 3  1984    USA*           34682
# 4  1985    USA*           38653
# /tmp/ipykernel_7714/1023559000.py:20: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_long['Emigrant_Count'] = df_long['Emigrant_Count'].fillna(0).astype(int)
